# %%
import numpy as np
import pandas as pd
import os
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
import joblib
# Out:
# d:\Users\Jonps\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Define base directory paths
base_dir = base_dir = r'd:\Users\Jonps\Documents\portfolio_triagem\Streamlit analizer panel'
data_dir = os.path.join(base_dir, 'data/')
model_dir = os.path.join(base_dir, 'models', 'linear_regression/')
os.makedirs(model_dir, exist_ok=True)

# Load the SP500 stock list
csv_file_path = os.path.join(base_dir, 'sp500_stocks.csv')
sp500_stocks = pd.read_csv(csv_file_path)

# %%
def train_linear_regression(symbol):
    # Load data
    data_path = os.path.join(data_dir, f'{symbol}.csv')
    if not os.path.exists(data_path):
        print(f'Data for {symbol} not found.')
        return

    stock_data = pd.read_csv(data_path)
    if stock_data.empty or 'Close' not in stock_data.columns:
        print(f'No valid data for {symbol}.')
        return

    stock_data['Date'] = pd.to_datetime(stock_data['Date'])
    stock_data.set_index('Date', inplace=True)

    if stock_data['Close'].isnull().all():
        print(f'No closing prices for {symbol}.')
        return

    # Prepare data
    scaler = MinMaxScaler(feature_range=(0, 1))
    try:
        scaled_data = scaler.fit_transform(stock_data['Close'].values.reshape(-1, 1))
    except ValueError as e:
        print(f'Error scaling data for {symbol}: {e}')
        return

    def create_dataset(data, look_back=100):
        X, Y = [], []
        for i in range(len(data) - look_back):
            X.append(data[i:(i + look_back), 0])
            Y.append(data[i + look_back, 0])
        return np.array(X), np.array(Y)

    look_back = 100
    x_train, y_train = create_dataset(scaled_data)

    if len(x_train) == 0 or len(y_train) == 0:
        print(f'Not enough data to create training set for {symbol}.')
        return

    # Build and train model
    model = LinearRegression()
    model.fit(x_train, y_train)

    # Save model
    model_path = os.path.join(model_dir, f'{symbol}_lr.pkl')
    joblib.dump(model, model_path)
    print(f'Model for {symbol} saved as {symbol}_lr.pkl')

# %%
# Train and save Linear Regression model for each SP500 stock
for symbol in sp500_stocks['Symbol']:
    train_linear_regression(symbol)
# Out:
# Model for A saved as A_lr.pkl
# Model for AAL saved as AAL_lr.pkl
# Model for AAPL saved as AAPL_lr.pkl
# Model for ABBV saved as ABBV_lr.pkl
# Model for ABNB saved as ABNB_lr.pkl
# Model for ABT saved as ABT_lr.pkl
# Model for ACGL saved as ACGL_lr.pkl
# Model for ACN saved as ACN_lr.pkl
# Model for ADBE saved as ADBE_lr.pkl
# Model for ADI saved as ADI_lr.pkl
# Model for ADM saved as ADM_lr.pkl
# Model for ADP saved as ADP_lr.pkl
# Model for ADSK saved as ADSK_lr.pkl
# Model for AEE saved as AEE_lr.pkl
# Model for AEP saved as AEP_lr.pkl
# Model for AES saved as AES_lr.pkl
# Model for AFL saved as AFL_lr.pkl
# Model for AIG saved as AIG_lr.pkl
# Model for AIZ saved as AIZ_lr.pkl
# Model for AJG saved as AJG_lr.pkl
# Model for AKAM saved as AKAM_lr.pkl
# Model for ALB saved as ALB_lr.pkl
# Model for ALGN saved as ALGN_lr.pkl
# Model for ALL saved as ALL_lr.pkl
# Model for ALLE saved as ALLE_lr.pkl
# Model for AMAT saved as AMAT_lr.pkl
# Model for AMCR saved as AMCR_lr.pkl
# Model for AMD saved as AMD_lr.pkl
# Model for AME saved as AME_lr.pkl
# Model for AMGN saved as AMGN_lr.pkl
# Model for AMP saved as AMP_lr.pkl
# Model for AMT saved as AMT_lr.pkl
# Model for AMZN saved as AMZN_lr.pkl
# Model for ANET saved as ANET_lr.pkl
# Model for ANSS saved as ANSS_lr.pkl
# Model for AON saved as AON_lr.pkl
# Model for AOS saved as AOS_lr.pkl
# Model for APA saved as APA_lr.pkl
# Model for APD saved as APD_lr.pkl
# Model for APH saved as APH_lr.pkl
# Model for APTV saved as APTV_lr.pkl
# Model for ARE saved as ARE_lr.pkl
# Model for ATO saved as ATO_lr.pkl
# Model for AVB saved as AVB_lr.pkl
# Model for AVGO saved as AVGO_lr.pkl
# Model for AVY saved as AVY_lr.pkl
# Model for AWK saved as AWK_lr.pkl
# Model for AXON saved as AXON_lr.pkl
# Model for AXP saved as AXP_lr.pkl
# Model for AZO saved as AZO_lr.pkl
# Model for BA saved as BA_lr.pkl
# Model for BAC saved as BAC_lr.pkl
# Model for BALL saved as BALL_lr.pkl
# Model for BAX saved as BAX_lr.pkl
# Model for BBWI saved as BBWI_lr.pkl
# Model for BBY saved as BBY_lr.pkl
# Model for BDX saved as BDX_lr.pkl
# Model for BEN saved as BEN_lr.pkl
# No valid data for BF.B.
# Model for BG saved as BG_lr.pkl
# Model for BIIB saved as BIIB_lr.pkl
# Model for BIO saved as BIO_lr.pkl
# Model for BK saved as BK_lr.pkl
# Model for BKNG saved as BKNG_lr.pkl
# Model for BKR saved as BKR_lr.pkl
# Model for BLDR saved as BLDR_lr.pkl
# Model for BLK saved as BLK_lr.pkl
# Model for BMY saved as BMY_lr.pkl
# Model for BR saved as BR_lr.pkl
# No valid data for BRK.B.
# Model for BRO saved as BRO_lr.pkl
# Model for BSX saved as BSX_lr.pkl
# Model for BWA saved as BWA_lr.pkl
# Model for BX saved as BX_lr.pkl
# Model for BXP saved as BXP_lr.pkl
# Model for C saved as C_lr.pkl
# Model for CAG saved as CAG_lr.pkl
# Model for CAH saved as CAH_lr.pkl
# Model for CARR saved as CARR_lr.pkl
# Model for CAT saved as CAT_lr.pkl
# Model for CB saved as CB_lr.pkl
# Model for CBOE saved as CBOE_lr.pkl
# Model for CBRE saved as CBRE_lr.pkl
# Model for CCI saved as CCI_lr.pkl
# Model for CCL saved as CCL_lr.pkl
# Model for CDNS saved as CDNS_lr.pkl
# Model for CDW saved as CDW_lr.pkl
# Model for CE saved as CE_lr.pkl
# Model for CEG saved as CEG_lr.pkl
# Model for CF saved as CF_lr.pkl
# Model for CFG saved as CFG_lr.pkl
# Model for CHD saved as CHD_lr.pkl
# Model for CHRW saved as CHRW_lr.pkl
# Model for CHTR saved as CHTR_lr.pkl
# Model for CI saved as CI_lr.pkl
# Model for CINF saved as CINF_lr.pkl
# Model for CL saved as CL_lr.pkl
# Model for CLX saved as CLX_lr.pkl
# Model for CMA saved as CMA_lr.pkl
# Model for CMCSA saved as CMCSA_lr.pkl
# Model for CME saved as CME_lr.pkl
# Model for CMG saved as CMG_lr.pkl
# Model for CMI saved as CMI_lr.pkl
# Model for CMS saved as CMS_lr.pkl
# Model for CNC saved as CNC_lr.pkl
# Model for CNP saved as CNP_lr.pkl
# Model for COF saved as COF_lr.pkl
# Model for COO saved as COO_lr.pkl
# Model for COP saved as COP_lr.pkl
# Model for COR saved as COR_lr.pkl
# Model for COST saved as COST_lr.pkl
# Model for CPB saved as CPB_lr.pkl
# Model for CPRT saved as CPRT_lr.pkl
# Model for CPT saved as CPT_lr.pkl
# Model for CRL saved as CRL_lr.pkl
# Model for CRM saved as CRM_lr.pkl
# Model for CSCO saved as CSCO_lr.pkl
# Model for CSGP saved as CSGP_lr.pkl
# Model for CSX saved as CSX_lr.pkl
# Model for CTAS saved as CTAS_lr.pkl
# Model for CTLT saved as CTLT_lr.pkl
# Model for CTRA saved as CTRA_lr.pkl
# Model for CTSH saved as CTSH_lr.pkl
# Model for CTVA saved as CTVA_lr.pkl
# Model for CVS saved as CVS_lr.pkl
# Model for CVX saved as CVX_lr.pkl
# Model for CZR saved as CZR_lr.pkl
# Model for D saved as D_lr.pkl
# Model for DAL saved as DAL_lr.pkl
# Model for DAY saved as DAY_lr.pkl
# Model for DD saved as DD_lr.pkl
# Model for DE saved as DE_lr.pkl
# Model for DECK saved as DECK_lr.pkl
# Model for DFS saved as DFS_lr.pkl
# Model for DG saved as DG_lr.pkl
# Model for DGX saved as DGX_lr.pkl
# Model for DHI saved as DHI_lr.pkl
# Model for DHR saved as DHR_lr.pkl
# Model for DIS saved as DIS_lr.pkl
# Model for DLR saved as DLR_lr.pkl
# Model for DLTR saved as DLTR_lr.pkl
# Model for DOC saved as DOC_lr.pkl
# Model for DOV saved as DOV_lr.pkl
# Model for DOW saved as DOW_lr.pkl
# Model for DPZ saved as DPZ_lr.pkl
# Model for DRI saved as DRI_lr.pkl
# Model for DTE saved as DTE_lr.pkl
# Model for DUK saved as DUK_lr.pkl
# Model for DVA saved as DVA_lr.pkl
# Model for DVN saved as DVN_lr.pkl
# Model for DXCM saved as DXCM_lr.pkl
# Model for EA saved as EA_lr.pkl
# Model for EBAY saved as EBAY_lr.pkl
# Model for ECL saved as ECL_lr.pkl
# Model for ED saved as ED_lr.pkl
# Model for EFX saved as EFX_lr.pkl
# Model for EG saved as EG_lr.pkl
# Model for EIX saved as EIX_lr.pkl
# Model for EL saved as EL_lr.pkl
# Model for ELV saved as ELV_lr.pkl
# Model for EMN saved as EMN_lr.pkl
# Model for EMR saved as EMR_lr.pkl
# Model for ENPH saved as ENPH_lr.pkl
# Model for EOG saved as EOG_lr.pkl
# Model for EPAM saved as EPAM_lr.pkl
# Model for EQIX saved as EQIX_lr.pkl
# Model for EQR saved as EQR_lr.pkl
# Model for EQT saved as EQT_lr.pkl
# Model for ES saved as ES_lr.pkl
# Model for ESS saved as ESS_lr.pkl
# Model for ETN saved as ETN_lr.pkl
# Model for ETR saved as ETR_lr.pkl
# Model for ETSY saved as ETSY_lr.pkl
# Model for EVRG saved as EVRG_lr.pkl
# Model for EW saved as EW_lr.pkl
# Model for EXC saved as EXC_lr.pkl
# Model for EXPD saved as EXPD_lr.pkl
# Model for EXPE saved as EXPE_lr.pkl
# Model for EXR saved as EXR_lr.pkl
# Model for F saved as F_lr.pkl
# Model for FANG saved as FANG_lr.pkl
# Model for FAST saved as FAST_lr.pkl
# Model for FCX saved as FCX_lr.pkl
# Model for FDS saved as FDS_lr.pkl
# Model for FDX saved as FDX_lr.pkl
# Model for FE saved as FE_lr.pkl
# Model for FFIV saved as FFIV_lr.pkl
# Model for FI saved as FI_lr.pkl
# Model for FICO saved as FICO_lr.pkl
# Model for FIS saved as FIS_lr.pkl
# Model for FITB saved as FITB_lr.pkl
# No valid data for FLT.
# Model for FMC saved as FMC_lr.pkl
# Model for FOX saved as FOX_lr.pkl
# Model for FOXA saved as FOXA_lr.pkl
# Model for FRT saved as FRT_lr.pkl
# Model for FSLR saved as FSLR_lr.pkl
# Model for FTNT saved as FTNT_lr.pkl
# Model for FTV saved as FTV_lr.pkl
# Model for GD saved as GD_lr.pkl
# Model for GE saved as GE_lr.pkl
# Model for GEHC saved as GEHC_lr.pkl
# Model for GEN saved as GEN_lr.pkl
# Model for GILD saved as GILD_lr.pkl
# Model for GIS saved as GIS_lr.pkl
# Model for GL saved as GL_lr.pkl
# Model for GLW saved as GLW_lr.pkl
# Model for GM saved as GM_lr.pkl
# Model for GNRC saved as GNRC_lr.pkl
# Model for GOOG saved as GOOG_lr.pkl
# Model for GOOGL saved as GOOGL_lr.pkl
# Model for GPC saved as GPC_lr.pkl
# Model for GPN saved as GPN_lr.pkl
# Model for GRMN saved as GRMN_lr.pkl
# Model for GS saved as GS_lr.pkl
# Model for GWW saved as GWW_lr.pkl
# Model for HAL saved as HAL_lr.pkl
# Model for HAS saved as HAS_lr.pkl
# Model for HBAN saved as HBAN_lr.pkl
# Model for HCA saved as HCA_lr.pkl
# Model for HD saved as HD_lr.pkl
# Model for HES saved as HES_lr.pkl
# Model for HIG saved as HIG_lr.pkl
# Model for HII saved as HII_lr.pkl
# Model for HLT saved as HLT_lr.pkl
# Model for HOLX saved as HOLX_lr.pkl
# Model for HON saved as HON_lr.pkl
# Model for HPE saved as HPE_lr.pkl
# Model for HPQ saved as HPQ_lr.pkl
# Model for HRL saved as HRL_lr.pkl
# Model for HSIC saved as HSIC_lr.pkl
# Model for HST saved as HST_lr.pkl
# Model for HSY saved as HSY_lr.pkl
# Model for HUBB saved as HUBB_lr.pkl
# Model for HUM saved as HUM_lr.pkl
# Model for HWM saved as HWM_lr.pkl
# Model for IBM saved as IBM_lr.pkl
# Model for ICE saved as ICE_lr.pkl
# Model for IDXX saved as IDXX_lr.pkl
# Model for IEX saved as IEX_lr.pkl
# Model for IFF saved as IFF_lr.pkl
# Model for ILMN saved as ILMN_lr.pkl
# Model for INCY saved as INCY_lr.pkl
# Model for INTC saved as INTC_lr.pkl
# Model for INTU saved as INTU_lr.pkl
# Model for INVH saved as INVH_lr.pkl
# Model for IP saved as IP_lr.pkl
# Model for IPG saved as IPG_lr.pkl
# Model for IQV saved as IQV_lr.pkl
# Model for IR saved as IR_lr.pkl
# Model for IRM saved as IRM_lr.pkl
# Model for ISRG saved as ISRG_lr.pkl
# Model for IT saved as IT_lr.pkl
# Model for ITW saved as ITW_lr.pkl
# Model for IVZ saved as IVZ_lr.pkl
# Model for J saved as J_lr.pkl
# Model for JBHT saved as JBHT_lr.pkl
# Model for JBL saved as JBL_lr.pkl
# Model for JCI saved as JCI_lr.pkl
# Model for JKHY saved as JKHY_lr.pkl
# Model for JNJ saved as JNJ_lr.pkl
# Model for JNPR saved as JNPR_lr.pkl
# Model for JPM saved as JPM_lr.pkl
# Model for K saved as K_lr.pkl
# Model for KDP saved as KDP_lr.pkl
# Model for KEY saved as KEY_lr.pkl
# Model for KEYS saved as KEYS_lr.pkl
# Model for KHC saved as KHC_lr.pkl
# Model for KIM saved as KIM_lr.pkl
# Model for KLAC saved as KLAC_lr.pkl
# Model for KMB saved as KMB_lr.pkl
# Model for KMI saved as KMI_lr.pkl
# Model for KMX saved as KMX_lr.pkl
# Model for KO saved as KO_lr.pkl
# Model for KR saved as KR_lr.pkl
# Model for KVUE saved as KVUE_lr.pkl
# Model for L saved as L_lr.pkl
# Model for LDOS saved as LDOS_lr.pkl
# Model for LEN saved as LEN_lr.pkl
# Model for LH saved as LH_lr.pkl
# Model for LHX saved as LHX_lr.pkl
# Model for LIN saved as LIN_lr.pkl
# Model for LKQ saved as LKQ_lr.pkl
# Model for LLY saved as LLY_lr.pkl
# Model for LMT saved as LMT_lr.pkl
# Model for LNT saved as LNT_lr.pkl
# Model for LOW saved as LOW_lr.pkl
# Model for LRCX saved as LRCX_lr.pkl
# Model for LULU saved as LULU_lr.pkl
# Model for LUV saved as LUV_lr.pkl
# Model for LVS saved as LVS_lr.pkl
# Model for LW saved as LW_lr.pkl
# Model for LYB saved as LYB_lr.pkl
# Model for LYV saved as LYV_lr.pkl
# Model for MA saved as MA_lr.pkl
# Model for MAA saved as MAA_lr.pkl
# Model for MAR saved as MAR_lr.pkl
# Model for MAS saved as MAS_lr.pkl
# Model for MCD saved as MCD_lr.pkl
# Model for MCHP saved as MCHP_lr.pkl
# Model for MCK saved as MCK_lr.pkl
# Model for MCO saved as MCO_lr.pkl
# Model for MDLZ saved as MDLZ_lr.pkl
# Model for MDT saved as MDT_lr.pkl
# Model for MET saved as MET_lr.pkl
# Model for META saved as META_lr.pkl
# Model for MGM saved as MGM_lr.pkl
# Model for MHK saved as MHK_lr.pkl
# Model for MKC saved as MKC_lr.pkl
# Model for MKTX saved as MKTX_lr.pkl
# Model for MLM saved as MLM_lr.pkl
# Model for MMC saved as MMC_lr.pkl
# Model for MMM saved as MMM_lr.pkl
# Model for MNST saved as MNST_lr.pkl
# Model for MO saved as MO_lr.pkl
# Model for MOH saved as MOH_lr.pkl
# Model for MOS saved as MOS_lr.pkl
# Model for MPC saved as MPC_lr.pkl
# Model for MPWR saved as MPWR_lr.pkl
# Model for MRK saved as MRK_lr.pkl
# Model for MRNA saved as MRNA_lr.pkl
# Model for MRO saved as MRO_lr.pkl
# Model for MS saved as MS_lr.pkl
# Model for MSCI saved as MSCI_lr.pkl
# Model for MSFT saved as MSFT_lr.pkl
# Model for MSI saved as MSI_lr.pkl
# Model for MTB saved as MTB_lr.pkl
# Model for MTCH saved as MTCH_lr.pkl
# Model for MTD saved as MTD_lr.pkl
# Model for MU saved as MU_lr.pkl
# Model for NCLH saved as NCLH_lr.pkl
# Model for NDAQ saved as NDAQ_lr.pkl
# Model for NDSN saved as NDSN_lr.pkl
# Model for NEE saved as NEE_lr.pkl
# Model for NEM saved as NEM_lr.pkl
# Model for NFLX saved as NFLX_lr.pkl
# Model for NI saved as NI_lr.pkl
# Model for NKE saved as NKE_lr.pkl
# Model for NOC saved as NOC_lr.pkl
# Model for NOW saved as NOW_lr.pkl
# Model for NRG saved as NRG_lr.pkl
# Model for NSC saved as NSC_lr.pkl
# Model for NTAP saved as NTAP_lr.pkl
# Model for NTRS saved as NTRS_lr.pkl
# Model for NUE saved as NUE_lr.pkl
# Model for NVDA saved as NVDA_lr.pkl
# Model for NVR saved as NVR_lr.pkl
# Model for NWS saved as NWS_lr.pkl
# Model for NWSA saved as NWSA_lr.pkl
# Model for NXPI saved as NXPI_lr.pkl
# Model for O saved as O_lr.pkl
# Model for ODFL saved as ODFL_lr.pkl
# Model for OKE saved as OKE_lr.pkl
# Model for OMC saved as OMC_lr.pkl
# Model for ON saved as ON_lr.pkl
# Model for ORCL saved as ORCL_lr.pkl
# Model for ORLY saved as ORLY_lr.pkl
# Model for OTIS saved as OTIS_lr.pkl
# Model for OXY saved as OXY_lr.pkl
# Model for PANW saved as PANW_lr.pkl
# Model for PARA saved as PARA_lr.pkl
# Model for PAYC saved as PAYC_lr.pkl
# Model for PAYX saved as PAYX_lr.pkl
# Model for PCAR saved as PCAR_lr.pkl
# Model for PCG saved as PCG_lr.pkl
# Model for PEG saved as PEG_lr.pkl
# Model for PEP saved as PEP_lr.pkl
# Model for PFE saved as PFE_lr.pkl
# Model for PFG saved as PFG_lr.pkl
# Model for PG saved as PG_lr.pkl
# Model for PGR saved as PGR_lr.pkl
# Model for PH saved as PH_lr.pkl
# Model for PHM saved as PHM_lr.pkl
# Model for PKG saved as PKG_lr.pkl
# Model for PLD saved as PLD_lr.pkl
# Model for PM saved as PM_lr.pkl
# Model for PNC saved as PNC_lr.pkl
# Model for PNR saved as PNR_lr.pkl
# Model for PNW saved as PNW_lr.pkl
# Model for PODD saved as PODD_lr.pkl
# Model for POOL saved as POOL_lr.pkl
# Model for PPG saved as PPG_lr.pkl
# Model for PPL saved as PPL_lr.pkl
# Model for PRU saved as PRU_lr.pkl
# Model for PSA saved as PSA_lr.pkl
# Model for PSX saved as PSX_lr.pkl
# Model for PTC saved as PTC_lr.pkl
# Model for PWR saved as PWR_lr.pkl
# No valid data for PXD.
# Model for PYPL saved as PYPL_lr.pkl
# Model for QCOM saved as QCOM_lr.pkl
# Model for QRVO saved as QRVO_lr.pkl
# Model for RCL saved as RCL_lr.pkl
# Model for REG saved as REG_lr.pkl
# Model for REGN saved as REGN_lr.pkl
# Model for RF saved as RF_lr.pkl
# Model for RHI saved as RHI_lr.pkl
# Model for RJF saved as RJF_lr.pkl
# Model for RL saved as RL_lr.pkl
# Model for RMD saved as RMD_lr.pkl
# Model for ROK saved as ROK_lr.pkl
# Model for ROL saved as ROL_lr.pkl
# Model for ROP saved as ROP_lr.pkl
# Model for ROST saved as ROST_lr.pkl
# Model for RSG saved as RSG_lr.pkl
# Model for RTX saved as RTX_lr.pkl
# Model for RVTY saved as RVTY_lr.pkl
# Model for SBAC saved as SBAC_lr.pkl
# Model for SBUX saved as SBUX_lr.pkl
# Model for SCHW saved as SCHW_lr.pkl
# Model for SHW saved as SHW_lr.pkl
# Model for SJM saved as SJM_lr.pkl
# Model for SLB saved as SLB_lr.pkl
# Model for SMCI saved as SMCI_lr.pkl
# Model for SNA saved as SNA_lr.pkl
# Model for SNPS saved as SNPS_lr.pkl
# Model for SO saved as SO_lr.pkl
# Model for SPG saved as SPG_lr.pkl
# Model for SPGI saved as SPGI_lr.pkl
# Model for SRE saved as SRE_lr.pkl
# Model for STE saved as STE_lr.pkl
# Model for STLD saved as STLD_lr.pkl
# Model for STT saved as STT_lr.pkl
# Model for STX saved as STX_lr.pkl
# Model for STZ saved as STZ_lr.pkl
# Model for SWK saved as SWK_lr.pkl
# Model for SWKS saved as SWKS_lr.pkl
# Model for SYF saved as SYF_lr.pkl
# Model for SYK saved as SYK_lr.pkl
# Model for SYY saved as SYY_lr.pkl
# Model for T saved as T_lr.pkl
# Model for TAP saved as TAP_lr.pkl
# Model for TDG saved as TDG_lr.pkl
# Model for TDY saved as TDY_lr.pkl
# Model for TECH saved as TECH_lr.pkl
# Model for TEL saved as TEL_lr.pkl
# Model for TER saved as TER_lr.pkl
# Model for TFC saved as TFC_lr.pkl
# Model for TFX saved as TFX_lr.pkl
# Model for TGT saved as TGT_lr.pkl
# Model for TJX saved as TJX_lr.pkl
# Model for TMO saved as TMO_lr.pkl
# Model for TMUS saved as TMUS_lr.pkl
# Model for TPR saved as TPR_lr.pkl
# Model for TRGP saved as TRGP_lr.pkl
# Model for TRMB saved as TRMB_lr.pkl
# Model for TROW saved as TROW_lr.pkl
# Model for TRV saved as TRV_lr.pkl
# Model for TSCO saved as TSCO_lr.pkl
# Model for TSLA saved as TSLA_lr.pkl
# Model for TSN saved as TSN_lr.pkl
# Model for TT saved as TT_lr.pkl
# Model for TTWO saved as TTWO_lr.pkl
# Model for TXN saved as TXN_lr.pkl
# Model for TXT saved as TXT_lr.pkl
# Model for TYL saved as TYL_lr.pkl
# Model for UAL saved as UAL_lr.pkl
# Model for UBER saved as UBER_lr.pkl
# Model for UDR saved as UDR_lr.pkl
# Model for UHS saved as UHS_lr.pkl
# Model for ULTA saved as ULTA_lr.pkl
# Model for UNH saved as UNH_lr.pkl
# Model for UNP saved as UNP_lr.pkl
# Model for UPS saved as UPS_lr.pkl
# Model for URI saved as URI_lr.pkl
# Model for USB saved as USB_lr.pkl
# Model for V saved as V_lr.pkl
# Model for VFC saved as VFC_lr.pkl
# Model for VICI saved as VICI_lr.pkl
# Model for VLO saved as VLO_lr.pkl
# Model for VLTO saved as VLTO_lr.pkl
# Model for VMC saved as VMC_lr.pkl
# Model for VRSK saved as VRSK_lr.pkl
# Model for VRSN saved as VRSN_lr.pkl
# Model for VRTX saved as VRTX_lr.pkl
# Model for VTR saved as VTR_lr.pkl
# Model for VTRS saved as VTRS_lr.pkl
# Model for VZ saved as VZ_lr.pkl
# Model for WAB saved as WAB_lr.pkl
# Model for WAT saved as WAT_lr.pkl
# Model for WBA saved as WBA_lr.pkl
# Model for WBD saved as WBD_lr.pkl
# Model for WDC saved as WDC_lr.pkl
# Model for WEC saved as WEC_lr.pkl
# Model for WELL saved as WELL_lr.pkl
# Model for WFC saved as WFC_lr.pkl
# Model for WM saved as WM_lr.pkl
# Model for WMB saved as WMB_lr.pkl
# Model for WMT saved as WMT_lr.pkl
# Model for WRB saved as WRB_lr.pkl
# Model for WRK saved as WRK_lr.pkl
# Model for WST saved as WST_lr.pkl
# Model for WTW saved as WTW_lr.pkl
# Model for WY saved as WY_lr.pkl
# Model for WYNN saved as WYNN_lr.pkl
# Model for XEL saved as XEL_lr.pkl
# Model for XOM saved as XOM_lr.pkl
# Model for XRAY saved as XRAY_lr.pkl
# Model for XYL saved as XYL_lr.pkl
# Model for YUM saved as YUM_lr.pkl
# Model for ZBH saved as ZBH_lr.pkl
# Model for ZBRA saved as ZBRA_lr.pkl
# Model for ZTS saved as ZTS_lr.pkl
